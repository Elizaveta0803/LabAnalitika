# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizaveta0803/LabAnalitika/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание 1

# %% [markdown]
# Напишите программу для численного вычисления определённого интеграла с помощью средств SciPy. Сравните результаты вычисления различными функциями интегрирования с точным решением.
#
#
# ![image.png](data:image/png;base64,...)

# %%
from scipy import *
from scipy.integrate import *
import math
import numpy as np
from numpy.lib.scimath import *
from scipy.integrate import simps
import sympy as sy

# %%
def f(x):
  return 1 / math.sin(x)
integrate.quad(f, 1.01, 0.5)
# Out:
# (-0.7724154756086484, 8.575534455975125e-15)

# %% [markdown]
# ![изображение_2021-04-15_202524.png](data:image/png;base64,...)

# %%
ar = math.log1p(math.tan(0.25)/math.tan(0.005))
print(ar)
# Out:
# 3.9525497629039155

# %% [markdown]
# # Задание 2

# %% [markdown]
# Напишите программу для численного решения обыкновенного дифференциального уравнения с заданным начальным условием с помощью средств SciPy. Сравните результат вычисления
# с точным решением. Нарисуйте графики точного и численного решений, а также относительной ошибки численного решения.

# %% [markdown]
# Пример
#
# ![image.png](data:image/png;base64,...)

# %%
import math
from scipy import integrate
from matplotlib import pyplot as plt
import numpy as np
def f(yf, t):
  v=yf[0]
  y=yf[1]
  f0= -y+np.sin(t)-np.cos(2*t)
  f1=v
  return [f0, f1]
ti=np.linspace(0,7*np.pi,1000)
x0=np.pi
v0=2.0
y0=[x0,v0]
sol = integrate.odeint(f,y0,ti)
y1=sol[:,0]
y2=sol[:,1]
fig = plt.figure()
ax = fig.add_subplot(111)

ax.set(title='Тригонометрическая функция')
ax.set_xlabel('t')
ax.set_ylabel('f')
ax.plot(ti,y1,color='grey')
ax.plot(ti, y2, 'g')
lgnd = ax.legend(['y1','y2'], shadow=True)
lgnd.get_frame().set_facecolor("#ffb19a")
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def F(s, t, b, c):
    dudt = s[1]
    dvdt = -b*s[1] - c*s[0]
    return [dudt, dvdt]

b = 0
c = 4
y0 = [1, 1]
t = np.linspace(-10, 10, 1000)
sol = odeint(F, y0, t, args=(b, c))
y1 = sol[:,0]
y2 = sol[:,1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set(title='Тригонометрическая функция')
ax.set_xlabel('t')
ax.set_ylabel('y')
ax.plot(t, y1, color = 'b', linewidth = 2)
ax.plot(t, y2, color = 'purple', linewidth = 2)
lgnd = ax.legend(['y1', 'y2'], loc='upper left')
lgnd.get_frame().set_facecolor('w')
plt.grid()
plt.show()
