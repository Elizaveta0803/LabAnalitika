# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizaveta0803/LabAnalitika/blob/main/%D0%9A%D0%BE%D0%BD%D1%82%D1%80%D0%BE%D0%BB%D1%8C_%D0%B7%D0%BD%D0%B0%D0%BD%D0%B8%D0%B9_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Seaborn library**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8222e711-7846-4729-84fe-8b3a31e6acbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8222e711-7846-4729-84fe-8b3a31e6acbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic (4).csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
titanic=pd.read_csv('titanic.csv')

# %% [markdown]
# # **Box plots**

# %%
sns.boxplot(titanic['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(x='Age', data=titanic)

# %% [markdown]
# **Kernel density estimate**

# %%
sns.kdeplot(titanic['Age'])

# %%
titanic
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
sns.kdeplot(titanic['Fare'])

# %% [markdown]
# # **Violin plot**

# %%
sns.violinplot(x='Pclass', y='Age', data=titanic)

# %% [markdown]
# # **Count plots**

# %%
sns.countplot(titanic['Survived'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Heatmap**

# %%
sns.heatmap(titanic.corr(),annot=True,cmap='YlGnBu')

# %% [markdown]
# # **Facet grid**

# %%
g = sns.FacetGrid(titanic, col='Sex',row='Survived')
g.map(plt.hist,'Age')

# %% [markdown]
# # **Regplot**

# %%
sns.regplot(x='Age',y='Fare',data=titanic)

# %% [markdown]
# # **lmplot**

# %%
sns.lmplot(x='Age',y='Fare',row='Survived',data=titanic,col='Sex')

# %% [markdown]
# # **Strip plot**

# %%
sns.stripplot(x='Survived',y='Age',data=titanic)

# %% [markdown]
# # **Swarm plot**

# %%
sns.swarmplot(x='Survived',y='Age',data=titanic)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 18.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ти типы графиков можно комбинировать с другими. Лучше всего это делать с violinplot.

# %%
sns.violinplot(x='Survived',y='Age',data=titanic,palette='rainbow')
sns.swarmplot(x='Survived',y='Age',data=titanic,color='black',size=3)

# %% [markdown]
# # **Pair plot**

# %%
sns.pairplot(data=titanic)

# %% [markdown]
# **в цветовой палитре**

# %%
sns.pairplot(titanic, hue='Sex', palette='Set1')

# %% [markdown]
# # **Joint plot**

# %%
sns.jointplot(x='Fare',y='Age',data=titanic)

# %% [markdown]
# # **Самостоятельное задание **

# %% [markdown]
# # **ЗАДАНИЕ 1**

# %% [markdown]
# В библиотеке Sklearn есть встроенный набор данных Iris. Он содержит образцы разных видов растений Ирис. Каждый образец содержит четыре атрибута: длина чашелистика, ширина чашелистика, длина лепестка, ширина лепестка и вид (Iris setosa, Iris versicolor и Iris virginica), а также 50 образцов каждого вида.
#
#
# 1.	Считать данные из этого набора данных в DataFrame.
# 2.	Создайте фигуру 10 на 5 с двумя subplots.
# 3.	На первом подзаголовке постройте длину лепестка в зависимости от ширины лепестка.
# 4.	На втором подзаголовке постройте график зависимости длины чашелистика от ширины чашелистика.
# 5.	Для каждого графика пометьте оси x и y и задайте заголовок.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# %%
data=load_iris()

# %%
iris=pd.DataFrame(data=data.data,columns=data.feature_names)
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris['species']=data.target
iris['species']=iris['species'].map({0:'setosa',1:'versicolor',2:'virginica'})
iris['species'].value_counts().plot(kind='bar')
fig=plt.figure(figsize=(10,5))

# %%
ax1=fig.add_subplot(121)
iris.plot(kind='scatter', x='petal length (cm)', y='petal width (cm)',ax=ax1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # **ЗАДАНИЕ 2**

# %% [markdown]
# Загрузите данные из набора данных (встроенного в Seaborn) с помощью функции load_dataset("tips"). Этот набор данных содержит общие суммы счетов и чаевые для разных клиентов, посещающих ресторан. Клиенты классифицируются по полу, предпочтениям в отношении курения, а также по дню и времени посещения.
#
# 1.	Создайте график, показывающий распределение (ленточная диаграмма ) общей суммы счета за курящие и некурящие, в таблице, содержащей значения времени и пола.
# 2.	Создайте график, чтобы показать взаимосвязь между «чаевыми» и «полным счетом» для: курящих мужчин, не курящих мужчин, курящих женщин, не курящих женщин.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # №1

# %%
ax = sns.stripplot(x="smoker", y="total_bill", hue="sex", data=tips, jitter=True)

# %%
ax2 = sns.stripplot(x="smoker", y="total_bill", hue="time", data=tips, jitter=True)

# %%
ax3 = sns.catplot(x="smoker", y="total_bill",
                hue="sex", col="time",
                data=tips, kind="strip",
                height=6, aspect=.7);

# %% [markdown]
# # №2

# %%
sns.lineplot(x="total_bill", y="tip", hue="smoker", style="sex", data=tips)
